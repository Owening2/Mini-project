# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get('https://movie.naver.com/movie/running/current.naver')
time.sleep(2)

# %%
def movie_info(black_widow):
    url = "https://movie.naver.com/movie/search/result.naver?query="+word+"&section=all&ie=utf8"
    return url

# %%
word = "범죄와의+전쟁"
url = movie_info(word)
driver.get(url)

# %%
def select_first(driver):
    first = driver.find_elements_by_css_selector("#old_content > ul.search_list_1 > li:nth-child(2) > dl > dt > a")[0]
    first.click()
    time.sleep(2)
    
select_first(driver)

# %%
def select_second(driver):
    second = driver.find_elements_by_css_selector("#movieEndTabMenu > li:nth-child(7) > a > em")[0]
    second.click()
    time.sleep(2)
    
select_second(driver)

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
print(soup.select("#content > div.article > div.section_group.section_group_frst > div"))
# Out:
# [<div class="obj_section">
# <div class="best_lines">
# <div class="title_area" id="scriptMovie">
# <h4 class="h_best_lines">
# <strong class="blind">명대사</strong>
# </h4>
# <div class="btn_help_area">
# <a class="btn_notice" href="javascript:void(0);" id="scriptGuide" role="button"><em class="blind">도움말</em></a>
# <div class="ly_notice" id="noticeLayer" style="display:none;">
# 									국내 개봉 영화인 경우 실제 영화를 관람한 이용자들만 명대사 등록이 가능합니다.<br/>실 관람 여부 확인을 위해 네이버 영화에서 예매하고 실제 관람한 이용자들만 등록이<br/>가능하며 영화와 상관없는 명대사는 신고를 통해 삭제될 수 있습니다.
# 									<button class="btn_close" id="layerCloseBtn" type="button"><em>닫기</em></button>
# </div>
# <script type="text/javascript">
#                                     jindo.$Element("scriptGuide").attach('click', function() {
#                                         jindo.$Element("noticeLayer").toggle();
#                                     });
#                                     jindo.$Element("layerCloseBtn").attach('click', function() {
# ...

# %%
def getReview(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    famous_line = soup.select("#_filtered_ment_0")

# %%
soup.select("#iframeDiv > ul > li")
# Out:
# []

# %%
#작성일 기준 평점, 좋아요, 나빠요로 저장(데이터 프레임)
#빈도수등 간단한 통계 분석
#1차 목표 명대사별 추천수 상위 50개까지 출력 and 순위
#2차 목표 배우별 명대사 개수 카운트

명대사 배우 추천수 추출하고 
for문 돌려서 다음 페이지 가서 또 반복 5페이지까지 그럼 50개 나오니까 상위 50가능
